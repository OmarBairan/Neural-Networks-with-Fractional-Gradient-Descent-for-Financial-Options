# %% [markdown]
# ----

# %% [markdown]
# # Artificial Neural Network for Approximating
# # the Theoretical Value of Financial Options
# # Gradient‐Descent-Type Method with Caputo Derivative

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.special import gamma
from timeit import default_timer as timer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Data Generation – Theoretical BSM Option Prices

# %%
# BSM Model for Option Pricing
# Black-Scholes-Merton (BSM) model for option pricing
# This function calculates the theoretical price of a European call or put option
# using the Black-Scholes-Merton formula.
# Parameters:
# S: Current price of the underlying asset
# K: Strike price of the option
# T: Time to expiration (in years)
# r: Risk-free interest rate (annualized)
# sigma: Volatility of the underlying asset (annualized)
# opcion: Type of option ('call' or 'put')
# Returns:
# The theoretical price of the option based on the BSM model.
# The function uses the cumulative distribution function (CDF) of the standard normal distribution
# to calculate the probabilities associated with the option's payoff at expiration.
# The BSM formula is derived from the Black-Scholes differential equation and assumes that the underlying
# asset follows a geometric Brownian motion with constant volatility and interest rate.
# The function returns the price of the option based on the specified type (call or put).
# The BSM model is widely used in finance for pricing European options and is a fundamental concept
# in financial mathematics. It provides a theoretical framework for understanding how options are priced
# based on the underlying asset's price, strike price, time to expiration, risk-free interest     

def BSM_option_price(S, K, T, r, sigma, option = 'call'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / \
    (sigma * np.sqrt(T)) 
    d2 = (np.log(S / K) + (r - 0.5 * sigma**2) * T) / \
    (sigma * np.sqrt(T))
    if option == 'call':
        precio = (S * norm.cdf(d1) - K * np.exp(-r * T) * \
                  norm.cdf(d2))
    if option == 'put':
        precio = (K * np.exp(-r * T) * norm.cdf(-d2) - S * \
                  norm.cdf(-d1))  
    return precio

# %% [markdown]
# ## Creation of DataFrame with Options Data

# %%
# List of Variables for the BSM Model
# L: Number of samples
# S: Current price of the underlying asset
# K: Strike price of the option
# T: Time to expiration (in years) 
# r: Risk-free interest rate (annualized)
# sigma: Volatility of the underlying asset (annualized)

L = 10000
S = np.linspace(80, 120, L)
K =  np.repeat(100, L)
T = np.repeat(0.25, L)
r = np.repeat(0.05, L)
sigma = np.repeat(0.3, L)

# %%
# Call Option Prices Calculation
# This code calculates the theoretical price of a European call option

C = [BSM_option_price(S[i], K[i], T[i], r[i], sigma[i],\
                       option = 'call') for i in range(L)]
print(C[:2])
# Out:
# [np.float64(0.48332457542773977), np.float64(0.4836922265470971)]

# %%
# Creation of DataFrame with Options Data
# This code creates a DataFrame containing the option data, including the underlying asset's price,
# strike price, time to expiration, risk-free interest rate, volatility, and the calculated option
# price. The DataFrame is structured to facilitate further analysis or modeling of the option pricing data

values = np.array([S, K, T, r, sigma, C])
values = values.T
columnas = ['S', 'K', 'T', 'r', 'sigma', 'C']
data = pd.DataFrame(data = values,  columns = columnas) 
data.head()
# Out:
#            S      K     T     r  sigma         C
# 0  80.000000  100.0  0.25  0.05    0.3  0.483325
# 1  80.004000  100.0  0.25  0.05    0.3  0.483692
# 2  80.008001  100.0  0.25  0.05    0.3  0.484060
# 3  80.012001  100.0  0.25  0.05    0.3  0.484428
# 4  80.016002  100.0  0.25  0.05    0.3  0.484797

# %%
# Create numpy arrays for features and target variable
# This code extracts the features (S, K, T, r, sigma) and the target variable (C) from the DataFrame
# and converts them into numpy arrays for further processing
# The features represent the input variables for the model, while the target variable represents
# the output variable that the model aims to predict. This structure is commonly used in machine learning
# and data analysis tasks where the goal is to learn a mapping from input features to output targets
# The features are the independent variables that influence the option price, while the target variable
# is the dependent variable that we want to predict or analyze. This separation allows for easier manipulation
# and analysis of the data, especially when applying machine learning algorithms or statistical models.

y = np.array(data[['C']])
X = np.array(data[['S', 'K', 'r','sigma','T']])

# %% [markdown]
# ## Data Transformation
# ### We transform the data to scale it using MinMaxScaler function

# %%
# MinMax transformation of data
# We transform the data to scale it using MinMaxScaler function
# This transformation scales the features and target variable to a range between 0 and 1,                               
# which is useful for many machine learning algorithms that perform better with normalized data.

scalerX = MinMaxScaler()
scalerX.fit(X)
X = scalerX.transform(X)
scalerY = MinMaxScaler()
scalerY.fit(y)
y = scalerY.transform(y)

# %% [markdown]
# -----

# %% [markdown]
# ## Artificial Neural Network

# %%
# Activation Functions Class 
# This class contains various activation functions and their derivatives, including ReLU, ELU, and
# their fractional derivatives using the Caputo definition. 

class Activation_Functions:

    #ReLU activation function
    @staticmethod
    def relu(x):
        return np.maximum(0, x)

    @staticmethod
    def relu_derivative(x):
        return np.where(x > 0, 1, 0)

    @staticmethod
    def relu_Caputo_frac_derivative(x, alpha_frac, a):
        return np.where(x > 0, abs(x-a)**(1-alpha_frac) / ((1-alpha_frac)*gamma(1-alpha_frac)), 0)


##################################################################################


# Gradient Descent Class
# This class implements the gradient descent optimization algorithm for updating the weights and biases
# of a neural network layer. It uses a specified learning rate to adjust the weights and biases
# based on the gradients computed during backpropagation. The update_weights method applies the gradient
# descent step to the layer's weights and biases, allowing the model to learn from the data
# and improve its predictions over time. The learning rate controls the size of the step taken in
# the direction of the gradient, influencing the convergence speed and stability of the training process.       

class Gradient_Descent:
    def __init__(self, learning_rate=0.001):
        self.learning_rate = learning_rate

    def update_weights(self, layer):
        layer.weights -= self.learning_rate * layer.dweights 
        layer.biases -= self.learning_rate * layer.dbiases   
        

# Backpropagation Class
# This class implements the backpropagation algorithm for training neural networks.
# It calculates the gradients of the loss function with respect to the model's predictions
# and propagates these gradients backward through the network layers to update the weights and biases.
# The backward method takes the predicted values, true values, and the layers of the network as inputs.
# It computes the initial gradients using the specified loss function and then iterates through
# the layers in reverse order, calling the backward method of each layer to compute the gradients.
# The gradients are then used to update the weights and biases of each layer.
class Backpropagation:
    def __init__(self, loss_function):
        self.loss_function = loss_function

    def backward(self, y_pred, y_true, layers):
        dvalues = self.loss_function.derivative(y_pred, y_true)
        for layer in reversed(layers):
            layer.backward(dvalues)
            dvalues = layer.dinputs




# Mean Squared Error Loss Class
# This class implements the Mean Squared Error (MSE) loss function.
class Loss_MeanSquaredError:
    def calculate(self, y_pred, y_true):
        return np.mean((y_true - y_pred) ** 2)

    def derivative(self, y_pred, y_true):
        return 2 * (y_pred - y_true) / y_true.shape[0] 

    def Caputo_loss_derivative(self, y_pred, y_true, alpha_frac=0.9, a=0):
        return 2/gamma(3-alpha_frac) * ((y_pred - y_true)-a)**(2-alpha_frac)
    


# Layer_Dense Class
# This class represents a dense layer in a neural network. It initializes the weights and biases,
# performs the forward pass by calculating the output of the layer, and computes the gradients during
# the backward pass. The weights are initialized using a random normal distribution scaled by 0.1,
# and the biases are initialized to a small constant value (0.01). The forward method computes the output of the layer
# by performing a dot product between the inputs and the weights, followed by adding the biases.
# The backward method calculates the gradients of the weights, biases,
# and inputs based on the gradients of the output (dvalues) received from the next layer
# during backpropagation. The gradients are computed using the chain rule, allowing the model to
# learn from the errors in the predictions and adjust the weights and biases accordingly.
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons, seed):
        np.random.seed(seed)
        self.weights = 0.1 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.ones((1, n_neurons))*0.01

    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.dot(inputs, self.weights) + self.biases

    def backward(self, dvalues):
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)

# %% [markdown]
# ## Variables and Hyperparameters for the Neural Network

# %%
# Random seed
seed=7
# Learning rate
l_rate = 0.17 
# Maximum number of iterations for training the neural network
epochs=5000
# Tolerance 
tolerance = 1e-4
# Order of the Caputo fractional derivative in layers 
alpha_frac = 0.95
# Order of the Caputo fractional derivative in loss function
alpha_frac_loss = 0.99
# Value of "a" for evaluating the Caputo fractional derivative in layers
a = 0 
# Value of "a" for evaluating the Caputo fractional derivative in loss function
a_loss = 0

# %% [markdown]
# ## Architecture and Training of the Artificial Neural Network

# %%
# Initialize Layers
dense1 = Layer_Dense(5, 32, seed)
dense2 = Layer_Dense(32, 32, seed)
dense3 = Layer_Dense(32, 32, seed)
dense4 = Layer_Dense(32, 1, seed)

# Initialize Activation Functions
activation_funcs = Activation_Functions()
# Initialize Loss Function
loss_function = Loss_MeanSquaredError()
# Initialize Gradient Descent
gd_optimizer = Gradient_Descent(learning_rate=l_rate)
# Initialize Backpropagation
backprop = Backpropagation(loss_function)


# Training Loop 
# This loop iterates through the specified number of epochs, performing forward and backward passes
# through the neural network layers, calculating the loss, and updating the weights and biases using
# gradient descent. The loss is calculated using the mean squared error function, and the gradients 
# are computed using the chain rule. The weights and biases are updated based on the gradients
# to minimize the loss function. The loop also keeps track of the lowest loss encountered during training
# and updates the weights and biases accordingly. If the loss falls below a specified tolerance,
# the training process is terminated early to prevent overfitting and unnecessary computations.

# Initialize variables
lowest_loss = float('inf')
loss_list = []
N=0

# Start training time count 
from timeit import default_timer as timer
start = timer()


# Training loop
for iteration in range(epochs):
   
    #########################################################################################################################
   
    # Forward pass

    #ReLU
    dense1.forward(X)
    activation1_output = activation_funcs.relu(dense1.output)
    dense2.forward(activation1_output)
    activation2_output = activation_funcs.relu(dense2.output)
    dense3.forward(activation2_output)
    activation3_output = activation_funcs.relu(dense3.output)
    dense4.forward(activation3_output)
    y_pred = dense4.output

    # #ELU
    # dense1.forward(X)
    # activation1_output = activation_funcs.elu(dense1.output)
    # dense2.forward(activation1_output)
    # activation2_output = activation_funcs.elu(dense2.output)
    # dense3.forward(activation2_output)
    # activation3_output = activation_funcs.elu(dense3.output)
    # dense4.forward(activation3_output)
    # y_pred = dense4.output


    # Calculate Loss Function
    loss = loss_function.calculate(y_pred, y)

    # Create a list of loss values
    loss_list.append(loss)


    #########################################################################################################################
    
    # Backward pass
    
    # Loss Funtion Gradient
    dvalues = loss_function.derivative(y_pred, y) 
    # dvalues = loss_function.Caputo_loss_derivative(y_pred, y, alpha_frac=alpha_frac_loss, a=a_loss) 
    dense4.backward(dvalues)


    # Select the activation function gradient to use by uncommenting the desired section 

    # # ReLU Activation Function Gradient Descent
    # dvalues = dense4.dinputs * activation_funcs.relu_derivative(dense3.output)
    # dense3.backward(dvalues)
    # dvalues = dense3.dinputs * activation_funcs.relu_derivative(dense2.output)
    # dense2.backward(dvalues)
    # dvalues = dense2.dinputs * activation_funcs.relu_derivative(dense1.output)
    # dense1.backward(dvalues)

    # ReLU Activation Function Gradient Descent with Caputo Fractional Derivative
    dvalues = dense4.dinputs * activation_funcs.relu_Caputo_frac_derivative(dense3.output, alpha_frac=alpha_frac, a=a)
    dense3.backward(dvalues)
    dvalues = dense3.dinputs * activation_funcs.relu_Caputo_frac_derivative(dense2.output, alpha_frac=alpha_frac, a=a)
    dense2.backward(dvalues)
    dvalues = dense2.dinputs * activation_funcs.relu_Caputo_frac_derivative(dense1.output, alpha_frac=alpha_frac, a=a)
    dense1.backward(dvalues)


# #########################################################################################################################
    
    # Update Weights and Biases
    # This section updates the weights and biases of each layer using the gradient descent optimizer.
    # The update_weights method of the Gradient_Descent class is called for each layer,
    # applying the calculated gradients to adjust the weights and biases in the direction that minimizes the loss
    # function. 

    # Optimization of weights with Gradient Descent or Fractional Gradient Descent
    gd_optimizer.update_weights(dense1)
    gd_optimizer.update_weights(dense2)
    gd_optimizer.update_weights(dense3)
    gd_optimizer.update_weights(dense4)

    #########################################################################################################################
    # Print the current iteration and loss
    # This section prints the current iteration number and the loss value to monitor the training progress.
    # Save the current weights and biases if the loss has decreased
    # This allows the model to keep track of the best-performing weights and biases during training,
    # ensuring that the model retains the best parameters found so far.
    if loss < lowest_loss:
        print("# Updated weighting, iteration: ", iteration+1, 
              '- Loss function: ', loss)
        best_dense1_weights = dense1.weights.copy()
        best_dense1_biases = dense1.biases.copy()
        best_dense2_weights = dense2.weights.copy()
        best_dense2_biases = dense2.biases.copy()
        best_dense3_weights = dense3.weights.copy()
        best_dense3_biases = dense3.biases.copy()
        best_dense4_weights = dense4.weights.copy()
        best_dense4_biases = dense4.biases.copy()
        lowest_loss = loss
    else:
        dense1.weights = best_dense1_weights.copy()
        dense1.biases = best_dense1_biases.copy()
        dense2.weights = best_dense2_weights.copy()
        dense2.biases = best_dense2_biases.copy()
        dense3.weights = best_dense3_weights.copy()
        dense3.biases = best_dense3_biases.copy()
        dense4.weights = best_dense4_weights.copy()
        dense4.biases = best_dense4_biases.copy()

    N=iteration + 1
    if loss <= tolerance:
        break
end = timer()

print("Training time: ", end - start)
print("Number of iterations: ", N)
# Out:
# # Updated weighting, iteration:  1 - Loss function:  0.20922521950420986
# # Updated weighting, iteration:  2 - Loss function:  0.1280827167483927
# # Updated weighting, iteration:  3 - Loss function:  0.10281979935134218
# # Updated weighting, iteration:  4 - Loss function:  0.09376674455033049
# # Updated weighting, iteration:  5 - Loss function:  0.09046547568647831
# # Updated weighting, iteration:  6 - Loss function:  0.08916576978660098
# # Updated weighting, iteration:  7 - Loss function:  0.08856816854143407
# # Updated weighting, iteration:  8 - Loss function:  0.0881893766680216
# # Updated weighting, iteration:  9 - Loss function:  0.08786161670056555
# # Updated weighting, iteration:  10 - Loss function:  0.08753813485602456
# # Updated weighting, iteration:  11 - Loss function:  0.08723850146828162
# # Updated weighting, iteration:  12 - Loss function:  0.08698028960977026
# # Updated weighting, iteration:  13 - Loss function:  0.08675595968805735
# # Updated weighting, iteration:  14 - Loss function:  0.08654392763420735
# # Updated weighting, iteration:  15 - Loss function:  0.08633015233964862
# # Updated weighting, iteration:  16 - Loss function:  0.08610857465152126
# # Updated weighting, iteration:  17 - Loss function:  0.0858785686917112
# # Updated weighting, iteration:  18 - Loss function:  0.08564121806735352
# # Updated weighting, iteration:  19 - Loss function:  0.08539804465468026
# # Updated weighting, iteration:  20 - Loss function:  0.08515080562171126
# # Updated weighting, iteration:  21 - Loss function:  0.08490066599912542
# # Updated weighting, iteration:  22 - Loss function:  0.08464801761660956
# # Updated weighting, iteration:  23 - Loss function:  0.0843929519651785
# # Updated weighting, iteration:  24 - Loss function:  0.08413547520583793
# # Updated weighting, iteration:  25 - Loss function:  0.08387571916612845
# # Updated weighting, iteration:  26 - Loss function:  0.08361408616617357
# # Updated weighting, iteration:  27 - Loss function:  0.08335106199642764
# # Updated weighting, iteration:  28 - Loss function:  0.08308688205754645
# # Updated weighting, iteration:  29 - Loss function:  0.08282122503461212
# # Updated weighting, iteration:  30 - Loss function:  0.08255308782411763
# # Updated weighting, iteration:  31 - Loss function:  0.08228100600542812
# # Updated weighting, iteration:  32 - Loss function:  0.08200319581862049
# # Updated weighting, iteration:  33 - Loss function:  0.08171740943389998
# # Updated weighting, iteration:  34 - Loss function:  0.08142172243417176
# # Updated weighting, iteration:  35 - Loss function:  0.08111511259030078
# # Updated weighting, iteration:  36 - Loss function:  0.08079734320114694
# # Updated weighting, iteration:  37 - Loss function:  0.08046911672395088
# # Updated weighting, iteration:  38 - Loss function:  0.0801316999743053
# # Updated weighting, iteration:  39 - Loss function:  0.0797854047712809
# # Updated weighting, iteration:  40 - Loss function:  0.07942041671414085
# # Updated weighting, iteration:  41 - Loss function:  0.07902563751988538
# # Updated weighting, iteration:  42 - Loss function:  0.07864137283563284
# # Updated weighting, iteration:  43 - Loss function:  0.07825740618132054
# # Updated weighting, iteration:  44 - Loss function:  0.07786427465735064
# # Updated weighting, iteration:  45 - Loss function:  0.07746239799080329
# # Updated weighting, iteration:  46 - Loss function:  0.07705124624153338
# # Updated weighting, iteration:  47 - Loss function:  0.07662884307198407
# # Updated weighting, iteration:  48 - Loss function:  0.07619333656157017
# # Updated weighting, iteration:  49 - Loss function:  0.0757432684800085
# # Updated weighting, iteration:  50 - Loss function:  0.0752776169417199
# # Updated weighting, iteration:  51 - Loss function:  0.07479550305673566
# # Updated weighting, iteration:  52 - Loss function:  0.07429614697727176
# # Updated weighting, iteration:  53 - Loss function:  0.07377869905115911
# # Updated weighting, iteration:  54 - Loss function:  0.07324223324390475
# # Updated weighting, iteration:  55 - Loss function:  0.072685839537899
# # Updated weighting, iteration:  56 - Loss function:  0.07210862209855161
# # Updated weighting, iteration:  57 - Loss function:  0.0715097430507382
# # Updated weighting, iteration:  58 - Loss function:  0.07088847959090831
# # Updated weighting, iteration:  59 - Loss function:  0.07024435800184402
# # Updated weighting, iteration:  60 - Loss function:  0.06957719534773817
# # Updated weighting, iteration:  61 - Loss function:  0.06888705286770729
# # Updated weighting, iteration:  62 - Loss function:  0.0681742877114375
# # Updated weighting, iteration:  63 - Loss function:  0.06743910238722445
# # Updated weighting, iteration:  64 - Loss function:  0.06668110233378025
# # Updated weighting, iteration:  65 - Loss function:  0.06589930365931103
# # Updated weighting, iteration:  66 - Loss function:  0.06509216740712118
# # Updated weighting, iteration:  67 - Loss function:  0.06425857522069542
# # Updated weighting, iteration:  68 - Loss function:  0.06339746624389758
# # Updated weighting, iteration:  69 - Loss function:  0.0625074222439005
# # Updated weighting, iteration:  70 - Loss function:  0.06158788621369019
# # Updated weighting, iteration:  71 - Loss function:  0.060637963635811025
# # Updated weighting, iteration:  72 - Loss function:  0.059656991305565996
# # Updated weighting, iteration:  73 - Loss function:  0.0586443811130855
# # Updated weighting, iteration:  74 - Loss function:  0.05759982891304349
# # Updated weighting, iteration:  75 - Loss function:  0.056523084482122704
# # Updated weighting, iteration:  76 - Loss function:  0.055413930169917955
# # Updated weighting, iteration:  77 - Loss function:  0.054272277175254464
# # Updated weighting, iteration:  78 - Loss function:  0.053097868121421594
# # Updated weighting, iteration:  79 - Loss function:  0.05189117957149692
# # Updated weighting, iteration:  80 - Loss function:  0.05065257395781771
# # Updated weighting, iteration:  81 - Loss function:  0.04938260787155419
# # Updated weighting, iteration:  82 - Loss function:  0.04808226238818381
# # Updated weighting, iteration:  83 - Loss function:  0.04675264045886912
# # Updated weighting, iteration:  84 - Loss function:  0.04539544897144304
# # Updated weighting, iteration:  85 - Loss function:  0.04401249433370735
# # Updated weighting, iteration:  86 - Loss function:  0.04260600593993786
# # Updated weighting, iteration:  87 - Loss function:  0.04117835253989041
# # Updated weighting, iteration:  88 - Loss function:  0.0397319484061374
# # Updated weighting, iteration:  89 - Loss function:  0.03827002603293948
# # Updated weighting, iteration:  90 - Loss function:  0.03679612984558095
# # Updated weighting, iteration:  91 - Loss function:  0.03531339648974782
# # Updated weighting, iteration:  92 - Loss function:  0.03382626481964729
# # Updated weighting, iteration:  93 - Loss function:  0.03233888757155834
# # Updated weighting, iteration:  94 - Loss function:  0.030855546394756912
# # Updated weighting, iteration:  95 - Loss function:  0.029381220406509242
# # Updated weighting, iteration:  96 - Loss function:  0.027920845984289202
# # Updated weighting, iteration:  97 - Loss function:  0.026479426004476784
# # Updated weighting, iteration:  98 - Loss function:  0.02506202983839165
# # Updated weighting, iteration:  99 - Loss function:  0.023673896959700635
# # Updated weighting, iteration:  100 - Loss function:  0.022319498313678222
# # Updated weighting, iteration:  101 - Loss function:  0.02100393812266025
# # Updated weighting, iteration:  102 - Loss function:  0.01973156056449138
# # Updated weighting, iteration:  103 - Loss function:  0.01850653813347773
# # Updated weighting, iteration:  104 - Loss function:  0.017332145075817915
# # Updated weighting, iteration:  105 - Loss function:  0.016211927836491547
# # Updated weighting, iteration:  106 - Loss function:  0.015148170068763437
# # Updated weighting, iteration:  107 - Loss function:  0.014143070054899513
# # Updated weighting, iteration:  108 - Loss function:  0.013197650833328356
# # Updated weighting, iteration:  109 - Loss function:  0.012313812860856282
# # Updated weighting, iteration:  110 - Loss function:  0.011491234137907215
# # Updated weighting, iteration:  111 - Loss function:  0.010727696790498604
# # Updated weighting, iteration:  112 - Loss function:  0.01002106222638528
# # Updated weighting, iteration:  113 - Loss function:  0.009369316390992966
# # Updated weighting, iteration:  114 - Loss function:  0.008769940154897356
# # Updated weighting, iteration:  115 - Loss function:  0.008220136101633878
# # Updated weighting, iteration:  116 - Loss function:  0.007717016869755739
# # Updated weighting, iteration:  117 - Loss function:  0.007257543109415994
# # Updated weighting, iteration:  118 - Loss function:  0.0068386579101392155
# # Updated weighting, iteration:  119 - Loss function:  0.00645727083359088
# # Updated weighting, iteration:  120 - Loss function:  0.006110275462789655
# # Updated weighting, iteration:  121 - Loss function:  0.005794745443010764
# # Updated weighting, iteration:  122 - Loss function:  0.005507855291068483
# # Updated weighting, iteration:  123 - Loss function:  0.005246938735167443
# # Updated weighting, iteration:  124 - Loss function:  0.0050094612923434504
# # Updated weighting, iteration:  125 - Loss function:  0.004793047762458802
# # Updated weighting, iteration:  126 - Loss function:  0.004595505735043939
# # Updated weighting, iteration:  127 - Loss function:  0.0044148234290989595
# # Updated weighting, iteration:  128 - Loss function:  0.004249156792540963
# # Updated weighting, iteration:  129 - Loss function:  0.004096832826281229
# # Updated weighting, iteration:  130 - Loss function:  0.003956309317692208
# # Updated weighting, iteration:  131 - Loss function:  0.0038261607482642703
# # Updated weighting, iteration:  132 - Loss function:  0.003705154764323369
# # Updated weighting, iteration:  133 - Loss function:  0.0035922040667034872
# # Updated weighting, iteration:  134 - Loss function:  0.0034863286385312777
# # Updated weighting, iteration:  135 - Loss function:  0.00338667161396336
# # Updated weighting, iteration:  136 - Loss function:  0.0032924732705439325
# # Updated weighting, iteration:  137 - Loss function:  0.0032030638178014185
# # Updated weighting, iteration:  138 - Loss function:  0.0031178769612653975
# # Updated weighting, iteration:  139 - Loss function:  0.0030364204075044115
# # Updated weighting, iteration:  140 - Loss function:  0.0029582712190833627
# # Updated weighting, iteration:  141 - Loss function:  0.0028830749490560536
# # Updated weighting, iteration:  142 - Loss function:  0.00281052142497875
# # Updated weighting, iteration:  143 - Loss function:  0.002740353348628657
# # Updated weighting, iteration:  144 - Loss function:  0.0026723584884513637
# # Updated weighting, iteration:  145 - Loss function:  0.002606355586529556
# # Updated weighting, iteration:  146 - Loss function:  0.002542208325990702
# # Updated weighting, iteration:  147 - Loss function:  0.002479788428032369
# # Updated weighting, iteration:  148 - Loss function:  0.0024189976048776037
# # Updated weighting, iteration:  149 - Loss function:  0.0023597463721285066
# # Updated weighting, iteration:  150 - Loss function:  0.002301979834917234
# # Updated weighting, iteration:  151 - Loss function:  0.002245645495865605
# # Updated weighting, iteration:  152 - Loss function:  0.0021907030087676234
# # Updated weighting, iteration:  153 - Loss function:  0.002137128549169656
# # Updated weighting, iteration:  154 - Loss function:  0.0020849041606720267
# # Updated weighting, iteration:  155 - Loss function:  0.0020340111498020697
# # Updated weighting, iteration:  156 - Loss function:  0.00198442852850961
# # Updated weighting, iteration:  157 - Loss function:  0.0019361456712877604
# # Updated weighting, iteration:  158 - Loss function:  0.0018891422401704056
# # Updated weighting, iteration:  159 - Loss function:  0.0018434111623716817
# # Updated weighting, iteration:  160 - Loss function:  0.0017989292271124377
# # Updated weighting, iteration:  161 - Loss function:  0.0017556805401608244
# # Updated weighting, iteration:  162 - Loss function:  0.0017136535796517009
# # Updated weighting, iteration:  163 - Loss function:  0.0016728276099825053
# # Updated weighting, iteration:  164 - Loss function:  0.0016331861048428451
# # Updated weighting, iteration:  165 - Loss function:  0.0015947117488531151
# # Updated weighting, iteration:  166 - Loss function:  0.0015573850492155816
# # Updated weighting, iteration:  167 - Loss function:  0.0015211797479213179
# # Updated weighting, iteration:  168 - Loss function:  0.0014860768141166628
# # Updated weighting, iteration:  169 - Loss function:  0.00145205384441348
# # Updated weighting, iteration:  170 - Loss function:  0.0014190872712300088
# # Updated weighting, iteration:  171 - Loss function:  0.0013871512413162505
# # Updated weighting, iteration:  172 - Loss function:  0.0013562187215619213
# # Updated weighting, iteration:  173 - Loss function:  0.00132626578950294
# # Updated weighting, iteration:  174 - Loss function:  0.0012972651963090115
# # Updated weighting, iteration:  175 - Loss function:  0.0012691919346260949
# # Updated weighting, iteration:  176 - Loss function:  0.0012420201078661233
# # Updated weighting, iteration:  177 - Loss function:  0.0012157221312373136
# # Updated weighting, iteration:  178 - Loss function:  0.001190271451194335
# # Updated weighting, iteration:  179 - Loss function:  0.001165639082384678
# # Updated weighting, iteration:  180 - Loss function:  0.00114179731636567
# # Updated weighting, iteration:  181 - Loss function:  0.001118722791546139
# # Updated weighting, iteration:  182 - Loss function:  0.0010963867926059845
# # Updated weighting, iteration:  183 - Loss function:  0.0010747698206976962
# # Updated weighting, iteration:  184 - Loss function:  0.001053844582373909
# # Updated weighting, iteration:  185 - Loss function:  0.0010335905096265205
# # Updated weighting, iteration:  186 - Loss function:  0.0010139864582831674
# # Updated weighting, iteration:  187 - Loss function:  0.000995007938627904
# # Updated weighting, iteration:  188 - Loss function:  0.0009766353734964892
# # Updated weighting, iteration:  189 - Loss function:  0.0009588457914070091
# # Updated weighting, iteration:  190 - Loss function:  0.0009416179157207129
# # Updated weighting, iteration:  191 - Loss function:  0.0009249327996091228
# # Updated weighting, iteration:  192 - Loss function:  0.0009087701817501278
# # Updated weighting, iteration:  193 - Loss function:  0.0008931123027990416
# # Updated weighting, iteration:  194 - Loss function:  0.0008779406502591549
# # Updated weighting, iteration:  195 - Loss function:  0.0008632390706864452
# # Updated weighting, iteration:  196 - Loss function:  0.0008489892150842423
# # Updated weighting, iteration:  197 - Loss function:  0.0008351763487305316
# # Updated weighting, iteration:  198 - Loss function:  0.0008217826985896929
# # Updated weighting, iteration:  199 - Loss function:  0.0008087939609378766
# # Updated weighting, iteration:  200 - Loss function:  0.0007961936553752281
# # Updated weighting, iteration:  201 - Loss function:  0.0007839693279981288
# # Updated weighting, iteration:  202 - Loss function:  0.0007721049137212136
# # Updated weighting, iteration:  203 - Loss function:  0.0007605887094926483
# # Updated weighting, iteration:  204 - Loss function:  0.0007494071749843919
# # Updated weighting, iteration:  205 - Loss function:  0.0007385475324417172
# # Updated weighting, iteration:  206 - Loss function:  0.0007279973873666394
# # Updated weighting, iteration:  207 - Loss function:  0.0007177457320386499
# # Updated weighting, iteration:  208 - Loss function:  0.0007077813398898517
# # Updated weighting, iteration:  209 - Loss function:  0.0006980931180137128
# # Updated weighting, iteration:  210 - Loss function:  0.0006886699280625338
# # Updated weighting, iteration:  211 - Loss function:  0.0006795020939940631
# # Updated weighting, iteration:  212 - Loss function:  0.0006705806599554305
# # Updated weighting, iteration:  213 - Loss function:  0.0006618959798680347
# # Updated weighting, iteration:  214 - Loss function:  0.0006534386066913589
# # Updated weighting, iteration:  215 - Loss function:  0.0006452000439177435
# # Updated weighting, iteration:  216 - Loss function:  0.0006371725373662002
# # Updated weighting, iteration:  217 - Loss function:  0.000629346716835593
# # Updated weighting, iteration:  218 - Loss function:  0.0006217164039498045
# # Updated weighting, iteration:  219 - Loss function:  0.0006142734952749141
# # Updated weighting, iteration:  220 - Loss function:  0.0006070110928061128
# # Updated weighting, iteration:  221 - Loss function:  0.0005999222136644062
# # Updated weighting, iteration:  222 - Loss function:  0.0005930009714401942
# # Updated weighting, iteration:  223 - Loss function:  0.0005862403036112012
# # Updated weighting, iteration:  224 - Loss function:  0.0005796347610661414
# # Updated weighting, iteration:  225 - Loss function:  0.000573178905787648
# # Updated weighting, iteration:  226 - Loss function:  0.0005668665353799886
# # Updated weighting, iteration:  227 - Loss function:  0.0005606927620140444
# # Updated weighting, iteration:  228 - Loss function:  0.0005546518187194228
# # Updated weighting, iteration:  229 - Loss function:  0.0005487399456410849
# # Updated weighting, iteration:  230 - Loss function:  0.0005429512639655683
# # Updated weighting, iteration:  231 - Loss function:  0.0005372821240653037
# # Updated weighting, iteration:  232 - Loss function:  0.0005317277937161801
# # Updated weighting, iteration:  233 - Loss function:  0.0005262836845384658
# # Updated weighting, iteration:  234 - Loss function:  0.000520945823976715
# # Updated weighting, iteration:  235 - Loss function:  0.0005157111629469976
# # Updated weighting, iteration:  236 - Loss function:  0.0005105752816642145
# # Updated weighting, iteration:  237 - Loss function:  0.000505534462723088
# # Updated weighting, iteration:  238 - Loss function:  0.0005005853259680584
# # Updated weighting, iteration:  239 - Loss function:  0.0004957250536090296
# # Updated weighting, iteration:  240 - Loss function:  0.0004909508048855726
# # Updated weighting, iteration:  241 - Loss function:  0.00048625827939930354
# # Updated weighting, iteration:  242 - Loss function:  0.0004816456290769557
# # Updated weighting, iteration:  243 - Loss function:  0.0004771102159522064
# # Updated weighting, iteration:  244 - Loss function:  0.00047264906999893716
# # Updated weighting, iteration:  245 - Loss function:  0.0004682597496261432
# # Updated weighting, iteration:  246 - Loss function:  0.00046393957950447665
# # Updated weighting, iteration:  247 - Loss function:  0.00045968693869482175
# # Updated weighting, iteration:  248 - Loss function:  0.00045549916054762055
# # Updated weighting, iteration:  249 - Loss function:  0.0004513738352410847
# # Updated weighting, iteration:  250 - Loss function:  0.0004473096439901482
# # Updated weighting, iteration:  251 - Loss function:  0.0004433036594425765
# # Updated weighting, iteration:  252 - Loss function:  0.0004393549152816779
# # Updated weighting, iteration:  253 - Loss function:  0.00043546166481952506
# # Updated weighting, iteration:  254 - Loss function:  0.0004316219290593719
# # Updated weighting, iteration:  255 - Loss function:  0.0004278335341769363
# # Updated weighting, iteration:  256 - Loss function:  0.0004240957139689317
# # Updated weighting, iteration:  257 - Loss function:  0.0004204066460783352
# # Updated weighting, iteration:  258 - Loss function:  0.00041676493330838004
# # Updated weighting, iteration:  259 - Loss function:  0.00041316967827583986
# # Updated weighting, iteration:  260 - Loss function:  0.00040961888733549436
# # Updated weighting, iteration:  261 - Loss function:  0.0004061115268440496
# # Updated weighting, iteration:  262 - Loss function:  0.00040264628717976667
# # Updated weighting, iteration:  263 - Loss function:  0.00039922244092611904
# # Updated weighting, iteration:  264 - Loss function:  0.0003958383894611322
# # Updated weighting, iteration:  265 - Loss function:  0.0003924937951001109
# # Updated weighting, iteration:  266 - Loss function:  0.00038918706937905565
# # Updated weighting, iteration:  267 - Loss function:  0.0003859176546244382
# # Updated weighting, iteration:  268 - Loss function:  0.00038268457537254214
# # Updated weighting, iteration:  269 - Loss function:  0.0003794864247463577
# # Updated weighting, iteration:  270 - Loss function:  0.00037632299220111533
# # Updated weighting, iteration:  271 - Loss function:  0.00037319355544467394
# # Updated weighting, iteration:  272 - Loss function:  0.00037009720723563035
# # Updated weighting, iteration:  273 - Loss function:  0.0003670333213692498
# # Updated weighting, iteration:  274 - Loss function:  0.00036400111819183953
# # Updated weighting, iteration:  275 - Loss function:  0.00036099990633355826
# # Updated weighting, iteration:  276 - Loss function:  0.0003580293991913653
# # Updated weighting, iteration:  277 - Loss function:  0.00035508885687591396
# # Updated weighting, iteration:  278 - Loss function:  0.000352178122634077
# # Updated weighting, iteration:  279 - Loss function:  0.00034929615190044
# # Updated weighting, iteration:  280 - Loss function:  0.0003464422737720294
# # Updated weighting, iteration:  281 - Loss function:  0.0003436161623117023
# # Updated weighting, iteration:  282 - Loss function:  0.00034081691246062406
# # Updated weighting, iteration:  283 - Loss function:  0.00033804399086709107
# # Updated weighting, iteration:  284 - Loss function:  0.0003352974600221616
# # Updated weighting, iteration:  285 - Loss function:  0.00033257613430855794
# # Updated weighting, iteration:  286 - Loss function:  0.000329880201147809
# # Updated weighting, iteration:  287 - Loss function:  0.00032720933278402285
# # Updated weighting, iteration:  288 - Loss function:  0.00032456251423034627
# # Updated weighting, iteration:  289 - Loss function:  0.000321939889484976
# # Updated weighting, iteration:  290 - Loss function:  0.00031934106891307035
# # Updated weighting, iteration:  291 - Loss function:  0.0003167657341970082
# # Updated weighting, iteration:  292 - Loss function:  0.00031421336457717534
# # Updated weighting, iteration:  293 - Loss function:  0.00031168337874467017
# # Updated weighting, iteration:  294 - Loss function:  0.0003091757422178447
# # Updated weighting, iteration:  295 - Loss function:  0.000306690359310117
# # Updated weighting, iteration:  296 - Loss function:  0.0003042267043755416
# # Updated weighting, iteration:  297 - Loss function:  0.0003017845792760256
# # Updated weighting, iteration:  298 - Loss function:  0.0002993636249942666
# # Updated weighting, iteration:  299 - Loss function:  0.0002969640542026551
# # Updated weighting, iteration:  300 - Loss function:  0.0002945851848461443
# # Updated weighting, iteration:  301 - Loss function:  0.00029222676697367324
# # Updated weighting, iteration:  302 - Loss function:  0.00028988840949979125
# # Updated weighting, iteration:  303 - Loss function:  0.0002875701324408959
# # Updated weighting, iteration:  304 - Loss function:  0.00028527192743207604
# # Updated weighting, iteration:  305 - Loss function:  0.0002829933564023006
# # Updated weighting, iteration:  306 - Loss function:  0.00028073426226647485
# # Updated weighting, iteration:  307 - Loss function:  0.0002784943593059702
# # Updated weighting, iteration:  308 - Loss function:  0.00027627331096005176
# # Updated weighting, iteration:  309 - Loss function:  0.00027407148377914855
# # Updated weighting, iteration:  310 - Loss function:  0.0002718881138135451
# # Updated weighting, iteration:  311 - Loss function:  0.0002697235317648618
# # Updated weighting, iteration:  312 - Loss function:  0.00026757736804948137
# # Updated weighting, iteration:  313 - Loss function:  0.0002654491566329624
# # Updated weighting, iteration:  314 - Loss function:  0.0002633390852019315
# # Updated weighting, iteration:  315 - Loss function:  0.0002612467817983269
# # Updated weighting, iteration:  316 - Loss function:  0.000259171628918943
# # Updated weighting, iteration:  317 - Loss function:  0.00025711397919714606
# # Updated weighting, iteration:  318 - Loss function:  0.0002550735319562899
# # Updated weighting, iteration:  319 - Loss function:  0.0002530501832340291
# # Updated weighting, iteration:  320 - Loss function:  0.00025104342609555516
# # Updated weighting, iteration:  321 - Loss function:  0.0002490534423479941
# # Updated weighting, iteration:  322 - Loss function:  0.0002470802531057597
# # Updated weighting, iteration:  323 - Loss function:  0.00024512353479342653
# # Updated weighting, iteration:  324 - Loss function:  0.00024318332221452978
# # Updated weighting, iteration:  325 - Loss function:  0.00024125942188640584
# # Updated weighting, iteration:  326 - Loss function:  0.00023935130776799954
# # Updated weighting, iteration:  327 - Loss function:  0.00023745893313393583
# # Updated weighting, iteration:  328 - Loss function:  0.00023558203502565148
# # Updated weighting, iteration:  329 - Loss function:  0.00023372044598532905
# # Updated weighting, iteration:  330 - Loss function:  0.00023187447594246358
# # Updated weighting, iteration:  331 - Loss function:  0.00023004377354491164
# # Updated weighting, iteration:  332 - Loss function:  0.00022822818652013646
# # Updated weighting, iteration:  333 - Loss function:  0.00022642755209449343
# # Updated weighting, iteration:  334 - Loss function:  0.00022464204633630924
# # Updated weighting, iteration:  335 - Loss function:  0.00022287138418340956
# # Updated weighting, iteration:  336 - Loss function:  0.00022111527892839736
# # Updated weighting, iteration:  337 - Loss function:  0.00021937394175033527
# # Updated weighting, iteration:  338 - Loss function:  0.0002176470959282775
# # Updated weighting, iteration:  339 - Loss function:  0.00021593460538193714
# # Updated weighting, iteration:  340 - Loss function:  0.0002142367246639099
# # Updated weighting, iteration:  341 - Loss function:  0.00021255317317903045
# # Updated weighting, iteration:  342 - Loss function:  0.00021088406749963516
# # Updated weighting, iteration:  343 - Loss function:  0.00020922911278200117
# # Updated weighting, iteration:  344 - Loss function:  0.00020758846351923475
# # Updated weighting, iteration:  345 - Loss function:  0.00020596180358403599
# # Updated weighting, iteration:  346 - Loss function:  0.00020434936546000884
# # Updated weighting, iteration:  347 - Loss function:  0.00020275097576674805
# # Updated weighting, iteration:  348 - Loss function:  0.00020116618718907592
# # Updated weighting, iteration:  349 - Loss function:  0.00019959518882379485
# # Updated weighting, iteration:  350 - Loss function:  0.00019803804216724722
# # Updated weighting, iteration:  351 - Loss function:  0.000196494465218152
# # Updated weighting, iteration:  352 - Loss function:  0.00019496466630572197
# # Updated weighting, iteration:  353 - Loss function:  0.00019344868152851899
# # Updated weighting, iteration:  354 - Loss function:  0.00019194641527820936
# # Updated weighting, iteration:  355 - Loss function:  0.00019045785007343517
# # Updated weighting, iteration:  356 - Loss function:  0.00018898279441904525
# # Updated weighting, iteration:  357 - Loss function:  0.00018752138535682702
# # Updated weighting, iteration:  358 - Loss function:  0.00018607364745087498
# # Updated weighting, iteration:  359 - Loss function:  0.00018463945479080726
# # Updated weighting, iteration:  360 - Loss function:  0.00018321883020045812
# # Updated weighting, iteration:  361 - Loss function:  0.00018181172029466716
# # Updated weighting, iteration:  362 - Loss function:  0.00018041807866890237
# # Updated weighting, iteration:  363 - Loss function:  0.0001790378025383704
# # Updated weighting, iteration:  364 - Loss function:  0.00017767087009484865
# # Updated weighting, iteration:  365 - Loss function:  0.00017631721799357415
# # Updated weighting, iteration:  366 - Loss function:  0.00017497690838519478
# # Updated weighting, iteration:  367 - Loss function:  0.00017364979692594215
# # Updated weighting, iteration:  368 - Loss function:  0.0001723357742076092
# # Updated weighting, iteration:  369 - Loss function:  0.00017103469801539213
# # Updated weighting, iteration:  370 - Loss function:  0.00016974652421368358
# # Updated weighting, iteration:  371 - Loss function:  0.0001684713062521852
# # Updated weighting, iteration:  372 - Loss function:  0.0001672088750659626
# # Updated weighting, iteration:  373 - Loss function:  0.00016595902489012954
# # Updated weighting, iteration:  374 - Loss function:  0.00016472171028219455
# # Updated weighting, iteration:  375 - Loss function:  0.00016349699867724364
# # Updated weighting, iteration:  376 - Loss function:  0.0001622845606511078
# # Updated weighting, iteration:  377 - Loss function:  0.0001610843926927638
# # Updated weighting, iteration:  378 - Loss function:  0.0001598965513840551
# # Updated weighting, iteration:  379 - Loss function:  0.0001587207594357524
# # Updated weighting, iteration:  380 - Loss function:  0.00015755706354255252
# # Updated weighting, iteration:  381 - Loss function:  0.00015640513955998502
# # Updated weighting, iteration:  382 - Loss function:  0.00015526511212179774
# # Updated weighting, iteration:  383 - Loss function:  0.00015413668832103925
# # Updated weighting, iteration:  384 - Loss function:  0.00015301990652955979
# # Updated weighting, iteration:  385 - Loss function:  0.0001519144691374642
# # Updated weighting, iteration:  386 - Loss function:  0.0001508204860057636
# # Updated weighting, iteration:  387 - Loss function:  0.00014973782362200924
# # Updated weighting, iteration:  388 - Loss function:  0.00014866619115294288
# # Updated weighting, iteration:  389 - Loss function:  0.00014760561802119307
# # Updated weighting, iteration:  390 - Loss function:  0.0001465560517725335
# # Updated weighting, iteration:  391 - Loss function:  0.00014551721775662313
# # Updated weighting, iteration:  392 - Loss function:  0.00014448913185786654
# # Updated weighting, iteration:  393 - Loss function:  0.00014347173957615018
# # Updated weighting, iteration:  394 - Loss function:  0.00014246481023302707
# # Updated weighting, iteration:  395 - Loss function:  0.00014146814667245829
# # Updated weighting, iteration:  396 - Loss function:  0.00014048181079562828
# # Updated weighting, iteration:  397 - Loss function:  0.00013950566001321585
# # Updated weighting, iteration:  398 - Loss function:  0.00013853956319371857
# # Updated weighting, iteration:  399 - Loss function:  0.00013758339544857407
# # Updated weighting, iteration:  400 - Loss function:  0.00013663706410938753
# # Updated weighting, iteration:  401 - Loss function:  0.0001357004115001405
# # Updated weighting, iteration:  402 - Loss function:  0.00013477315007363197
# # Updated weighting, iteration:  403 - Loss function:  0.00013385538335855708
# # Updated weighting, iteration:  404 - Loss function:  0.0001329469754419412
# # Updated weighting, iteration:  405 - Loss function:  0.0001320478256289408
# # Updated weighting, iteration:  406 - Loss function:  0.0001311577938368137
# # Updated weighting, iteration:  407 - Loss function:  0.00013027672221388426
# # Updated weighting, iteration:  408 - Loss function:  0.00012940457205246042
# # Updated weighting, iteration:  409 - Loss function:  0.0001285413987228881
# # Updated weighting, iteration:  410 - Loss function:  0.00012768740446363356
# # Updated weighting, iteration:  411 - Loss function:  0.00012684272850343258
# # Updated weighting, iteration:  412 - Loss function:  0.00012600727244150366
# # Updated weighting, iteration:  413 - Loss function:  0.00012518087672795596
# # Updated weighting, iteration:  414 - Loss function:  0.00012436350091378032
# # Updated weighting, iteration:  415 - Loss function:  0.00012355496857242783
# # Updated weighting, iteration:  416 - Loss function:  0.00012275533376009365
# # Updated weighting, iteration:  417 - Loss function:  0.0001219643451686792
# # Updated weighting, iteration:  418 - Loss function:  0.00012118184420522115
# # Updated weighting, iteration:  419 - Loss function:  0.00012040770554422484
# # Updated weighting, iteration:  420 - Loss function:  0.00011964194554350615
# # Updated weighting, iteration:  421 - Loss function:  0.0001188843473192481
# # Updated weighting, iteration:  422 - Loss function:  0.00011813479010794816
# # Updated weighting, iteration:  423 - Loss function:  0.00011739311213803436
# # Updated weighting, iteration:  424 - Loss function:  0.00011665933610088488
# # Updated weighting, iteration:  425 - Loss function:  0.0001159332064166506
# # Updated weighting, iteration:  426 - Loss function:  0.0001152147560466863
# # Updated weighting, iteration:  427 - Loss function:  0.00011450376262738136
# # Updated weighting, iteration:  428 - Loss function:  0.00011380020310958105
# # Updated weighting, iteration:  429 - Loss function:  0.00011310408315692342
# # Updated weighting, iteration:  430 - Loss function:  0.00011241509144860001
# # Updated weighting, iteration:  431 - Loss function:  0.00011173337945530102
# # Updated weighting, iteration:  432 - Loss function:  0.0001110587395337535
# # Updated weighting, iteration:  433 - Loss function:  0.0001103911883620557
# # Updated weighting, iteration:  434 - Loss function:  0.0001097304327979308
# # Updated weighting, iteration:  435 - Loss function:  0.00010907648803973866
# # Updated weighting, iteration:  436 - Loss function:  0.00010842919069985661
# # Updated weighting, iteration:  437 - Loss function:  0.00010778831077023323
# # Updated weighting, iteration:  438 - Loss function:  0.00010715383138047067
# # Updated weighting, iteration:  439 - Loss function:  0.00010652549042973532
# # Updated weighting, iteration:  440 - Loss function:  0.00010590332736849644
# # Updated weighting, iteration:  441 - Loss function:  0.00010528720322002564
# # Updated weighting, iteration:  442 - Loss function:  0.00010467693315493962
# # Updated weighting, iteration:  443 - Loss function:  0.00010407250727146807
# # Updated weighting, iteration:  444 - Loss function:  0.00010347381499754724
# # Updated weighting, iteration:  445 - Loss function:  0.00010288064412797511
# # Updated weighting, iteration:  446 - Loss function:  0.00010229308530936458
# # Updated weighting, iteration:  447 - Loss function:  0.0001017109758194618
# # Updated weighting, iteration:  448 - Loss function:  0.00010113426122753327
# # Updated weighting, iteration:  449 - Loss function:  0.00010056272545281421
# # Updated weighting, iteration:  450 - Loss function:  9.999640843695873e-05
# Training time:  9.14432204199693
# Number of iterations:  450

# %% [markdown]
# ## Loss Function Plot

# %%
# Plotting the Loss Function
plt.figure(figsize=(10, 8))
plt.plot(loss_list)
plt.title("Loss Function - Fractional Gradient Descent")
plt.xlabel('Epochs')
plt.ylabel('Loss Function')
plt.show;

# %% [markdown]
# ## Obtaining Values in the Original Scale

# %%
# Inverse transformation of the data
# This code transforms the predicted and actual values back to their original scale using the inverse transform method
# of the MinMaxScaler. 
yy = scalerY.inverse_transform(y)
yy_pred = scalerY.inverse_transform(y_pred)
y_obs = np.array(data['C']).reshape(len(data['C']),1)

# %% [markdown]
# ## Errors plot

# %%
# Error Calculation and Plotting
errors = (yy_pred-yy)
plt.figure(figsize=(10, 8))
plt.plot(S, errors)
plt.title("Errors from NN Prices and BSM Model")
plt.xlabel('Price of Underlying Asset - S')
plt.ylabel('Errors')
plt.show;

# %% [markdown]
# ## Plotting the results

# %%
# Gráfica de valores y, y_pred

plt.figure(figsize=(10, 8))
plt.plot(S, yy, c='b', label = "Price BSM")
plt.plot(S, yy_pred, c='Red', label = "Price RNA")
plt.title("Trainig Data - Prices from BSM Model and NN Model Fractional Gradient Descent")
plt.xlabel('Price of Underlying Asset - S')
plt.ylabel('y_pred, y')
plt.legend()
plt.show;

# %% [markdown]
# -----

# %% [markdown]
# ## Evaluate the NN using new data

# %%
# New data for evaluation

L_ = 1000
S_ = np.linspace(60, 140, L_)
K_ =  np.repeat(100, L_)
T_ = np.repeat(0.25, L_)
r_ = np.repeat(0.05, L_)
sigma_ = np.repeat(0.3, L_)

# %%
# Call option price
C_ = [BSM_option_price(S_[i], K_[i], T_[i], r_[i], sigma_[i], option = 'call') for i in range(L_)]

# %%
# Organize data into a numpy array

values_ = np.array([S_, K_, T_, r_, sigma_, C_])
values_ = values_.T

# %%
# Create Data Frame from Numpy Array

columns = ['S', 'K', 'T', 'r', 'sigma', 'C']
data_ = pd.DataFrame(data = values_,  columns = columns) 
data_
# Out:
#              S      K     T     r  sigma          C
# 0     60.00000  100.0  0.25  0.05    0.3   0.001347
# 1     60.08008  100.0  0.25  0.05    0.3   0.001395
# 2     60.16016  100.0  0.25  0.05    0.3   0.001444
# 3     60.24024  100.0  0.25  0.05    0.3   0.001494
# 4     60.32032  100.0  0.25  0.05    0.3   0.001546
# ..         ...    ...   ...   ...    ...        ...
# 995  139.67968  100.0  0.25  0.05    0.3  40.984177
# 996  139.75976  100.0  0.25  0.05    0.3  41.063579
# 997  139.83984  100.0  0.25  0.05    0.3  41.142988
# 998  139.91992  100.0  0.25  0.05    0.3  41.222404
# 999  140.00000  100.0  0.25  0.05    0.3  41.301827
#
# [1000 rows x 6 columns]

# %%
# Use the trained model to predict new data

xx = np.array(data_[['S', 'K', 'r','sigma','T']])
X_new = scalerX.transform(xx)
dense1.forward(X_new)
activation1_output = activation_funcs.relu(dense1.output)
dense2.forward(activation1_output)
activation2_output = activation_funcs.relu(dense2.output)
dense3.forward(activation2_output)
activation3_output = activation_funcs.relu(dense3.output)
dense4.forward(activation3_output)
y_new = dense4.output
Call_NN = scalerY.inverse_transform(y_new)

# %%
C_= np.asarray(C_).reshape(L_,1)

# %%
# Errors

error_NN = Call_NN - C_
error_NN.shape
# Out:
# (1000, 1)

# %% [markdown]
# ## Plot Errors

# %%
# Plotting the errors for the new data

plt.figure(figsize=(10, 8))
plt.title("Ourt of Sample Errors from NN Prices and BSM Model")
plt.xlabel('Price of Underlying Asset - S')
plt.ylabel('Errors')
plt.plot(S_, error_NN)
plt.show;

# %% [markdown]
# ## Plot results

# %%
# Plotting results y, y_pred

plt.figure(figsize=(10, 8))
plt.plot(S_, C_, c='b', label = "Price BSM")
plt.plot(S_, Call_NN, c='Red', label = "Price ANN")
plt.title("Test Data - Prices from BSM Model and NN Model Fractional Gradient Descent")
plt.xlabel('Price of Underlying Asset - S')
plt.ylabel('y_pred, y')
plt.legend()
plt.show;

# %%
# Root Mean Square Error (RMSE) Calculation
# This code calculates the Root Mean Square Error (RMSE) between the predicted option prices
# from the neural network and the actual option prices calculated using the BSM model using new data.
RMSE_NN = np.sqrt(np.sum((C_ - Call_NN)**2))
print(RMSE_NN)
# Out:
# 77.7766753287716
